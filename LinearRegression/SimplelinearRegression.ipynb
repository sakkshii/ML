# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df= pd.read_csv('/content/drive/MyDrive/ML-SelfStudyCode/Salary_dataset.csv')
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
x = df.iloc[:, 1:-1].values
y = df.iloc[:, -1].values
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split( x, y, test_size=0.2, random_state=2)

# %%
class SimpleLinearRegression:
  def __init__(self) -> None:
    self.b = None
    self.m = None

  def fit(self, x_train, y_train):
    # dont need to use for loop --> numpy can iterate over it
    x_mean= np.mean(x_train)
    y_mean= np.mean(y_train)

    self.m= ((x_train - x_mean) * (y_train - y_mean)).sum() / ((x_train - x_mean)**2).sum()
    self.b= y_mean - (self.m * x_mean)

  def predict(self, x_test):
    return self.m * x_test + self.b

# %%
print(x_train)
print(y_train)
# Out:
# [[ 8.3]
#  [ 3.1]
#  [ 2.1]
#  [ 6.9]
#  [ 3. ]
#  [ 9.7]
#  [ 4.1]
#  [ 2.3]
#  [ 4. ]
#  [ 5.2]
#  [10.4]
#  [ 9.1]
#  [ 5.4]
#  [ 1.6]
#  [ 3.3]
#  [ 9.6]
#  [ 8.8]
#  [ 6. ]
#  [ 4.1]
#  [ 8. ]
#  [10.6]
#  [ 4.2]
#  [ 5. ]
#  [ 3.3]]
# [113813.  60151.  43526.  91739.  56643. 112636.  56958.  39892.  63219.
#   66030. 122392. 105583.  83089.  37732.  54446. 116970. 109432.  81364.
#   55795. 101303. 121873.  57082.  67939.  64446.]

# %%
model = SimpleLinearRegression()
model.fit(x_train, y_train)

# %%
model.predict(3.3)
# Out:
# np.float64(78502.20833333333)
